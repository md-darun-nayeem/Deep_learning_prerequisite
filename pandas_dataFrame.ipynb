# %% [markdown]
# <a href="https://colab.research.google.com/github/md-darun-nayeem/Deep_learning_prerequisite/blob/main/pandas_dataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# list to dataFrame

student_data =[
    [1,20,30],
    [25,15,65],
    [12,22,32]
]
stu = pd.DataFrame(student_data,columns=['iq','marks','package'])

# %%
# using dictionary

# %%
student_data ={
    'id': [1,2,3],
    'marks': [45,65,76],
    'package': ['cse','bba','hsc']
}
pd.DataFrame(student_data)
# Out:
#    id  marks package
# 0   1     45     cse
# 1   2     65     bba
# 2   3     76     hsc

# %%
movies = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DL prerequisite/Pandas/movies.csv')

# %%
ipl = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DL prerequisite/Pandas/ipl-matches.csv')

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
movies.shape
# Out:
# (1629, 18)

# %%
ipl.shape
# Out:
# (950, 20)

# %%
movies.dtypes  # object means string
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
student_data.values
# Out:
# <function dict.values>

# %%
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
ipl.tail(3)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                  Team2  \
# 947             Delhi Daredevils       Rajasthan Royals
# 948              Kings XI Punjab    Chennai Super Kings
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver            WinningTeam    WonBy  Margin method  \
# 947          bat         N       Delhi Daredevils  Wickets     9.0    NaN
# ...

# %%
movies.sample(5) # randomly finds 5 rows
# Out:
#                                title_x    imdb_id  \
# 492               Kya Dilli Kya Lahore  tt2063745
# 1219              Bachke Rehna Re Baba  tt0451639
# 1119  Salaam-e-Ishq: A Tribute to Love  tt0485272
# 1101       MP3: Mera Pehla Pehla Pyaar  tt0860454
# 722                   Rush (2012 film)  tt2256514
#
#                                             poster_path  \
# 492   https://upload.wikimedia.org/wikipedia/en/9/9f...
# 1219  https://upload.wikimedia.org/wikipedia/en/9/99...
# 1119  https://upload.wikimedia.org/wikipedia/en/thum...
# 1101  https://upload.wikimedia.org/wikipedia/en/thum...
# 722   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 492   https://en.wikipedia.org/wiki/Kya_Dilli_Kya_La...
# 1219  https://en.wikipedia.org/wiki/Bachke_Rehna_Re_...
# 1119  https://en.wikipedia.org/wiki/Salaam-e-Ishq:_A...
# 1101  https://en.wikipedia.org/wiki/MP3:_Mera_Pehla_...
# ...

# %%
ipl.info() # to find out missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
# duplicated
movies.duplicated().sum()
# Out:
# 0

# %%
stu
# Out:
#    iq  percent  lpa
# 0   1       20   30
# 1  25       15   65
# 2  12       22   32

# %%
stu.rename(columns={'marks':'percent','package':'lpa'},inplace=True)

# %%
stu.sum()
# Out:
# iq          38
# percent     57
# lpa        127
# dtype: int64

# %%
stu.sum(axis=0)
# Out:
# iq          38
# percent     57
# lpa        127
# dtype: int64

# %%
stu.mean(axis=1)
# Out:
# 0    17.0
# 1    35.0
# 2    22.0
# dtype: float64

# %%
stu.std()
# Out:
# iq         12.013881
# percent     3.605551
# lpa        19.655364
# dtype: float64

# %%
stu.var()
# Out:
# iq         144.333333
# percent     13.000000
# lpa        386.333333
# dtype: float64

# %%
stu.median()
# Out:
# iq         12.0
# percent    20.0
# lpa        32.0
# dtype: float64

# %%
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
movies['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
type(movies['title_x'])
# Out:
# pandas.core.series.Series

# %%
ipl['Venue']
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
movies[['title_x','year_of_release','actors']].head(3)
# Out:
#                                 title_x  year_of_release  \
# 0              Uri: The Surgical Strike             2019
# 1                         Battalion 609             2019
# 2  The Accidental Prime Minister (film)             2019
#
#                                               actors
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1  Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2  Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...

# %%
type(movies[['title_x','year_of_release','actors']])
# Out:
# pandas.core.frame.DataFrame

# %%
student_info ={
    'names': ['naim','seikh','rasel'],
    'id': [1,2,3],
    'marks': [45,65,76],
    'package': ['cse','bba','hsc']
}
stu1 = pd.DataFrame(student_info)
stu1.set_index('names',inplace=True)
stu1
# Out:
#        id  marks package
# names
# naim    1     45     cse
# seikh   2     65     bba
# rasel   3     76     hsc

# %% [markdown]
# iloc : searches using index position
# - iloc fetching works with index
#
# loc: searches using index lebels
# - loc fetching works with col names

# %%
movies.iloc[0]
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %%
type(movies.iloc[0])
# Out:
# pandas.core.series.Series

# %%
movies.iloc[0:5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies.iloc[5:11]
# Out:
#                              title_x    imdb_id  \
# 5                        Soni (film)  tt6078866
# 6                      Fraud Saiyaan  tt5013008
# 7                         Bombairiya  tt4971258
# 8   Manikarnika: The Queen of Jhansi  tt6903440
# 9                   Thackeray (film)  tt7777196
# 10                            Amavas  tt8396186
#
#                                           poster_path  \
# 5   https://upload.wikimedia.org/wikipedia/en/thum...
# 6   https://upload.wikimedia.org/wikipedia/en/thum...
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 8   https://upload.wikimedia.org/wikipedia/en/thum...
# 9   https://upload.wikimedia.org/wikipedia/en/thum...
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                             wiki_link  \
# 5           https://en.wikipedia.org/wiki/Soni_(film)
# 6         https://en.wikipedia.org/wiki/Fraud_Saiyaan
# 7            https://en.wikipedia.org/wiki/Bombairiya
# ...

# %%
stu1
# Out:
#        id  marks package
# names
# naim    1     45     cse
# seikh   2     65     bba
# rasel   3     76     hsc

# %%
stu1.loc['naim']
# Out:
# id           1
# marks       45
# package    cse
# Name: naim, dtype: object

# %%
stu1.loc['naim':'seikh']
# Out:
#        id  marks package
# names
# naim    1     45     cse
# seikh   2     65     bba

# %%
stu1.loc['naim':'seikh':2] # alternate
# Out:
#        id  marks package
# names
# naim    1     45     cse

# %%
movies.iloc[0:3,0:3]  # fetching col and rows
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:3, 'title_x':'poster_path']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# Filter a DataFrame

# %%
# Question: Find out the winning team names

ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
mask = ipl['MatchNumber'] == 'Final'
new_df = ipl[mask]
new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
ipl[ipl['MatchNumber']=='Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# How many super over ?

ipl[ipl['SuperOver']=='Y'].shape
# Out:
# (14, 20)

# %%
ipl[ipl['SuperOver']=='Y'].shape[0]
# Out:
# 14

# %%
# How many matches has csk won in kolkata

ipl[ipl['City']=='Kolkata']
# Out:
#           ID     City        Date   Season  MatchNumber  \
# 2    1312198  Kolkata  2022-05-25     2022   Eliminator
# 3    1312197  Kolkata  2022-05-24     2022  Qualifier 1
# 207  1178422  Kolkata  2019-04-28     2019           47
# 211  1178418  Kolkata  2019-04-25     2019           43
# 219  1178410  Kolkata  2019-04-19     2019           35
# ..       ...      ...         ...      ...          ...
# 908   336025  Kolkata  2008-05-18  2007/08           41
# 915   336017  Kolkata  2008-05-13  2007/08           35
# 922   336010  Kolkata  2008-05-08  2007/08           29
# 934   335997  Kolkata  2008-04-29  2007/08           16
# 945   335986  Kolkata  2008-04-20  2007/08            4
#
#                            Team1                        Team2  \
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 207        Kolkata Knight Riders               Mumbai Indians
# ...

# %%
# & is bit wise and ,works with binary operator

ipl[(ipl['City']=='Kolkata') & (ipl['WinningTeam']=='Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
# Toss winner is match winner in percentage

ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0]*100
# Out:
# 51.473684210526315

# %%
# movies with rating higher than 8 and votes>10000

movies[(movies['imdb_rating'] > 8.5) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 0

# %%
# Action movies with rating higher than 7.5
# mask1 = movies['genres'].str.split('|').apply(lambda x:'Action' in x)
mask1 = movies['genres'].str.contains('Action')
mask2 = movies['imdb_rating'] > 7.5

movies[mask1 & mask2].shape[0]
# Out:
# 33

# %%
stu1
# Out:
#        id  marks package
# names
# naim    1     45     cse
# seikh   2     65     bba
# rasel   3     76     hsc

# %%
stu1['section'] = 'Int46'

# %%
stu1
# Out:
#        id  marks package section
# names
# naim    1     45     cse   Int46
# seikh   2     65     bba   Int46
# rasel   3     76     hsc   Int46

# %%
# from existing ones
movies.dropna(inplace=True)

# %%
# add lead actor

movies['lead actor'] = movies['actors'].str.split('|').apply(lambda x:x[0])
movies.head(2)
# Out:
#           title_x    imdb_id  \
# 11      Gully Boy  tt2395469
# 34  Yeh Hai India  tt5525846
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                       wiki_link        title_y original_title  \
# 11      https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy      Gully Boy
# 34  https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India  Yeh Hai India
#
#     is_adult  year_of_release runtime                  genres  imdb_rating  \
# 11         0             2019     153             Drama|Music          8.2
# 34         0             2017     128  Action|Adventure|Drama          5.7
#
#     imdb_votes                                              story  \
# 11       22440  Gully Boy is a film about a 22-year-old boy "M...
# 34         169  Yeh Hai India  follows the story of a 25 years...
#
# ...

# %%
# astype
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['ID'] = ipl['ID'].astype('int32')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# ipl['Season'] = ipl['Season'].astype('category')
ipl['Team1'] = ipl['Team1'].astype('category')
ipl['Team2'] = ipl['Team2'].astype('category')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...
